# %%
import matplotlib.pyplot as plt
import numpy as np
from dataclasses import replace
import importlib
from astropy.table import Table

import run_config
import utils_lya_halo

from run_config import cfg, smoke
from utils_lya_halo import run_extract, read_galaxy_fits, run_stack, measure, plotting
from utils_lya_halo import PipelineConfig

# %%
# #Smoke test with N galaxies
# N_smoke = 3
# _ = run_extract(smoke(N_smoke))

# %%
#Run in terminal to see current memory usage
#   watch -n1 cat /sys/fs/cgroup/memory.current

# %% [markdown]
# # Extracting the data - may take a while

# %%
catalog_path = "catalogs/lya_halo_catalog_cuts/lya_mosdef_catalog_KEEP.fits"
catalog  = Table.read(catalog_path, format='fits')
catalog[:5]
# Out:
# <Table length=5>
# INDEX FIELD  CATALOG   ID  ... AGN_MEX_APPLIED VALID         EBV
# int64 bytes6  bytes6 int64 ...       bool       bool       float64
# ----- ------ ------- ----- ... --------------- ----- -------------------
#     0  AEGIS  MOSDEF 12870 ...           False  True 0.05545413223247336
#     4  AEGIS  MOSDEF 12046 ...           False  True 0.24313699163434704
#     5  AEGIS  MOSDEF 11578 ...           False  True 0.16648453703375132
#     7  AEGIS  MOSDEF 11299 ...           False  True  0.4396975403167308
#     8  AEGIS  MOSDEF 10503 ...           False  True  0.5529336070979379

# %%
N = None

LYA_REST = 1215.67
runner = run_extract(replace(cfg, 
    num_gal         = N,
    field           = "COSMOS",
    catalog         = "MOSDEF",
    catalog_path    = catalog_path,
    bins            = [0, 10, 16, 24, 36, 60, 100, 180, 350, 600, 1000, 2000, 3000],
    bin_mode        = "kpc",
    mask_method     = "segmap",
    id_col          = "ID",
    bg_inner_arcsec = 80.0,
    bg_outer_arcsec = 90.0,
    min_bg_fibers   = 9999999,
    fiber_combine_method   = "biweight",
    bg_smooth_method= "interp_gauss",
    bg_smooth_sigma_A      = 30.0,
    line_mask_halfwidth_A  = 10.0, 
    mass_col        = "MASS_50",
    z_col           = "z",
    rest_delta      = 0.2,
    rest_wave_min   = 1100,
    rest_wave_max   = 1700,
    rest_density    = True,
    cut_radial_bin  = -1,
    min_good_wave   = 100,
    line_window = [LYA_REST-4, LYA_REST+4],
    n_bootstrap = 1000))
# Out:
# Loaded COSMOS: 132 exposures, 34944 fibers, 1036 wavelength pixels
# Same RA and bad_fiber_mask shape? True
# Bad fibers: 552954
# Good fibers: 4059654
# Fraction bad: 0.12
# Fibers off mask footprint: 0.000%
#   0%|          | 0/278 [00:00<?, ?it/s]
